# %%
from graph import GraphLoader

# %%
sf_graph = GraphLoader()

# %%
G = sf_graph.get_graph()
# Out:
# Loading cached DRIVE graph from backend/data/sf_drive_graph.graphml...

# %%
print(f"nodes: {G.number_of_nodes()}, edges: {G.number_of_edges()}")
# Out:
# nodes: 9997, edges: 27556

# %%
import json

# %%
import os

# %%
os.curdir
# Out:
# '.'

# %%
with open("/Users/georgiavonminden/time-prisms/backend/backend/data/real_osm_cameras.json") as f:
    cams = json.load(f)

# %%
cams
# Out:
# [{'id': 'OSM-ALPR-1',
#   'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-122.47548354545455, 37.8071685],
#      [-122.47556877272727, 37.80728553045997],
#      [-122.47573922727274, 37.80728553045997],
#      [-122.47582445454546, 37.8071685],
#      [-122.47573922727274, 37.807051469540035],
#      [-122.47556877272727, 37.807051469540035],
#      [-122.47548354545455, 37.8071685]]]},
#   'properties': {'label': 'OSM-1',
#    'type': 'alpr_osm',
#    'manufacturer': 'Unknown ALPR',
#    'operator': 'Golden Gate Bridge Highway and Transportation District',
#    'osm_id': "('node', 65374006)"}},
#  {'id': 'OSM-ALPR-2',
#   'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-122.47584764545455, 37.7655162],
#      [-122.47593287272727, 37.76563323045997],
#      [-122.47610332727274, 37.76563323045997],
#      [-122.47618855454546, 37.7655162],
#      [-122.47610332727274, 37.76539916954003],
# ...

# %%
cams[0]
# Out:
# {'id': 'OSM-ALPR-1',
#  'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-122.47548354545455, 37.8071685],
#     [-122.47556877272727, 37.80728553045997],
#     [-122.47573922727274, 37.80728553045997],
#     [-122.47582445454546, 37.8071685],
#     [-122.47573922727274, 37.807051469540035],
#     [-122.47556877272727, 37.807051469540035],
#     [-122.47548354545455, 37.8071685]]]},
#  'properties': {'label': 'OSM-1',
#   'type': 'alpr_osm',
#   'manufacturer': 'Unknown ALPR',
#   'operator': 'Golden Gate Bridge Highway and Transportation District',
#   'osm_id': "('node', 65374006)"}}
